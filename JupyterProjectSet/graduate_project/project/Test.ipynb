# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#测试" data-toc-modified-id="测试-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>测试</a></span></li><li><span><a href="#制作词云图" data-toc-modified-id="制作词云图-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>制作词云图</a></span></li><li><span><a href="#数据分析" data-toc-modified-id="数据分析-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数据分析</a></span></li></ul></div>

# %% [markdown]
# #### 测试

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import wordcloud

# xpoints = np.array([0, 6])
# ypoints = np.array([0, 100])

# plt.plot(xpoints, ypoints)
# plt.show()

# %% [markdown]
# #### 制作词云图

# %%
# import jieba
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud
 
# text = open(r"../data/comment_positive.txt", encoding="utf-8").read()  # 标明文本路径，打开
 
# # 生成对象
# wc = WordCloud(font_path = "msyh.ttc",width=500, height=400, mode="RGBA", background_color=None).generate(text)
# # 显示词云图
# plt.imshow(wc, interpolation="bilinear")
# plt.axis("off")
# plt.show()
 
# #保存文件
# wc.to_file("../resule/WordCloud_1.png")

# %% [markdown]
# #### 数据分析

# %%
# pip install OpenHowNet

# %%
# import jieba
# help(jieba)

# %%
# from jieba import analyse
# help(analyse.extract_tags)

# %%
# help(str.strip)

# %%
# a_string = ' jisuanji '
# a_string = a_string.strip()
# a_string = a_string.strip('j')
# a_string

# %%
# from gensim import corpora, models

# %%
# import gensim.test

# %%
# help(gensim.test)

# %%
# help(models.coherencemodel)

# %%
# help(models.LdaModel)

# %%
# help(models.LdaModel.log_perplexity)

# %%
# help(round)

# %%
# import sklearn

# %%
# help(sklearn)

# %%
# import sklearn.feature_extraction

# %%
# help(sklearn.feature_extraction)

# %%
# help(sklearn.feature_extraction.text.CountVectorizer)

# %%
# import sklearn.model_selection

# %%
# help(sklearn.model_selection)

# %%
# import pandas as pd

# %%
# help(pd.DataFrame)

# %%
# import sklearn.neighbors as sb

# %%
# help(sb.KNeighborsClassifier)

# %%
# import csv

# %%
# a_list = ['aaa', 'bbb', 'ccc', 'ddd', 'eee', 'fff']

# with open('hello.csv', 'w', encoding='utf-8') as fp:
#     for line in a_list:
#         fp.write(line)
#         fp.write('\n')
# print('done')
# Out:
# done

# %%
import requests

# %%
requests.get('https://www.baidu.com')
# Out:
# <Response [200]>
